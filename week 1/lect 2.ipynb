# %%
import numpy as np

# %% [markdown]
# # ex 1

# %%
# 1) Create a numpy array [1,2,3] using arange
x=np.arange(1,4)
x
# Out:
# array([1, 2, 3])

# %% [markdown]
# # Ex 2
# ![image.png](attachment:image.png)

# %%
x=np.arange(1,4)
y=np.arange(4,7)
z=x+y
z
# Out:
# array([5, 7, 9])

# %% [markdown]
# # Ex 3 (HADAMARD Product - element wise multiplication)
# ![image.png](attachment:image.png)

# %%
z=x*y # element wise product
z
# Out:
# array([ 4, 10, 18])

# %% [markdown]
# # ex 4 : Scaling Vectors
# ![image.png](attachment:image.png)

# %%
y=3*x
y
# Out:
# array([3, 6, 9])

# %% [markdown]
# # ex 5
# ![image.png](attachment:image.png)
# # create a list from 1 to 10000001 and timeit to multiple each element by 2

# %%
x_list=list(range(1,1000001))
# %timeit x_list_by_2=[2*i for i in x_list]

x_np=np.arange(1,1000001)
# %timeit x_np_by_2=2*x_np
# Out:
# 99.9 ms ± 5.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.54 ms ± 25.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
99.9/1.54
# Out:
# 64.87012987012987
